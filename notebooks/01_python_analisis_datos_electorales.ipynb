# %% [markdown]
# # Python para el análisis de datos
# ## Introducción a las Ciencias Sociales Computacionales
# ## Facultad de Ciencias Sociales, Universidad de Buenos Aires, 2023
# ### Juan Manuel Pérez y Rodolfo Elbert
#
# Click acá para abrir en Colab
#
# ![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jmperez/iscsc/blob/master/01_icsc_regresion.ipynb)
#
# En esta notebook vamos a analizar datos de las últimas PASO (Agosto 2023), obtenidos del [Observatorio de La Izquierda Diario](https://observatorio.laizquierdadiario.com/consultas).
#
#
# Inspirado un poco en este análisis de ["Los Mitos del votante de Milei"](https://medium.com/@VoteBetta/los-mitos-del-votante-de-milei-ae497168535) -- de otro docente de la casa.
#
#
# ## Datos tabulares
#
# En primer lugar, vamos a usar la librería `pandas` para leer los datos de un archivo `csv` y mostrarlos en pantalla.
#
# [pandas](https://pandas.pydata.org/) es una librería de Python para el análisis de datos. En particular, nos permite trabajar con datos tabulares (filas y columnas) de manera muy eficiente y fácil, del estilo de las tablas de Excel. Para quienes tengan experiencia en R, `pandas` es el equivalente a los DataFrame
#
# Un `csv` (comma separated values) es un archivo de texto plano que contiene datos separados por comas. Es un formato muy común para guardar datos tabulares (similar al .xlsx)

# %%
# !pip install seaborn pandas statsmodels
# Out:
# Requirement already satisfied: seaborn in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: statsmodels in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: patsy>=0.5.2 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from statsmodels) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: six in /home/jmperez/projects/docencia/csc-2023/.venv/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
import pandas as pd

# Si corren local, usar esta línea
# df = pd.read_csv('../data/pba_paso_2023.csv')

df = pd.read_csv('https://raw.githubusercontent.com/finiteautomata/csc-2023/main/data/pba_paso_2023.csv')
# Out:
# /tmp/ipykernel_24939/3362892980.py:6: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://raw.githubusercontent.com/finiteautomata/csc-2023/main/data/pba_paso_2023.csv')

# %% [markdown]
# Vamos a ver algunos elementos de esta tabla.

# %%
df.head(20)
# Out:
#     Unnamed: 0  cod_categoria   nom_categoria  cod_distrito  nom_distrito  \
# 0            0              1  PRESIDENCIALES             2  Buenos Aires
# 1            1              1  PRESIDENCIALES             2  Buenos Aires
# 2            2              1  PRESIDENCIALES             2  Buenos Aires
# 3            3              1  PRESIDENCIALES             2  Buenos Aires
# 4            4              1  PRESIDENCIALES             2  Buenos Aires
# 5            5              1  PRESIDENCIALES             2  Buenos Aires
# 6            6              1  PRESIDENCIALES             2  Buenos Aires
# 7            7              1  PRESIDENCIALES             2  Buenos Aires
# 8            8              1  PRESIDENCIALES             2  Buenos Aires
# 9            9              1  PRESIDENCIALES             2  Buenos Aires
# 10          10              1  PRESIDENCIALES             2  Buenos Aires
# 11          11              1  PRESIDENCIALES             2  Buenos Aires
# 12          12              1  PRESIDENCIALES             2  Buenos Aires
# 13          13              1  PRESIDENCIALES             2  Buenos Aires
# 14          14              1  PRESIDENCIALES             2  Buenos Aires
# 15          15              1  PRESIDENCIALES             2  Buenos Aires
# 16          16              1  PRESIDENCIALES             2  Buenos Aires
# 17          17              1  PRESIDENCIALES             2  Buenos Aires
# 18          18              1  PRESIDENCIALES             2  Buenos Aires
# 19          19              1  PRESIDENCIALES             2  Buenos Aires
#
#     cod_seccion nom_seccion cod_circuito nom_circuito  cod_lugar  ...  \
# 0            61  La Matanza        00626        00626       5951  ...
# 1            61  La Matanza        00626        00626       5951  ...
# 2            61  La Matanza        00626        00626       5951  ...
# 3            61  La Matanza        00626        00626       5951  ...
# 4            61  La Matanza        00626        00626       5951  ...
# 5            61  La Matanza        00626        00626       5951  ...
# 6            61  La Matanza        00626        00626       5951  ...
# 7            61  La Matanza        00626        00626       5951  ...
# 8            61  La Matanza        00626        00626       5951  ...
# 9            61  La Matanza        00626        00626       5951  ...
# 10           61  La Matanza        00626        00626       5951  ...
# 11           61  La Matanza        00626        00626       5951  ...
# 12           61  La Matanza        00626        00626       5951  ...
# 13           61  La Matanza        00626        00626       5951  ...
# 14           61  La Matanza        00626        00626       5951  ...
# 15           61  La Matanza        00626        00626       5951  ...
# 16           61  La Matanza        00626        00626       5951  ...
# 17           61  La Matanza        00626        00626       5951  ...
# 18           61  La Matanza        00626        00626       5951  ...
# 19           61  La Matanza        00626        00626       5951  ...
#
#    nom_mesa cod_tipo_voto nom_tipo_voto cod_agrupacion_int  cod_agrupacion  \
# 0    00001X             p      positivo                134             134
# 1    00001X             p      positivo                132             132
# 2    00001X             p      positivo                135             135
# 3    00001X             p      positivo                136             136
# 4    00001X             p      positivo                133             133
# 5    00001X             p      positivo                 94              94
# 6    00001X             p      positivo                 13              13
# 7    00001X             p      positivo                 20              20
# 8    00001X             p      positivo                 40              40
# 9    00001X             p      positivo                 95              95
# 10   00001X             p      positivo                131             131
# 11   00001X             p      positivo                 57              57
# 12   00001X             p      positivo                 92              92
# 13   00001X             p      positivo                 90              90
# 14   00001X             p      positivo                137             137
# 15   00001X             b       blancos                  0               0
# 16   00001X             n         nulos                  0               0
# 17   00001X             c       comando                  0               0
# 18   00001X             i    impugnados                  0               0
# 19   00001X             r    recurridos                  0               0
#
#                                     nom_agrupacion orden  votos  porcentaje  \
# 0                              UNION POR LA PATRIA     0     82       33.61
# 1                             JUNTOS POR EL CAMBIO     0     75       30.74
# 2                               LA LIBERTAD AVANZA     0     70       28.69
# 3   FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD     0     13        5.33
# 4                         HACEMOS POR NUESTRO PAIS     0      3        1.23
# 5                                   PROYECTO JOVEN     0      1        0.41
# 6                         MOVIMIENTO AL SOCIALISMO     0      0        0.00
# 7                     UNION DEL CENTRO DEMOCRATICO     0      0        0.00
# 8                        MOVIMIENTO LIBRES DEL SUR     0      0        0.00
# 9                          FRENTE PATRIOTA FEDERAL     0      0        0.00
# 10                                 FRENTE LIBER.AR     0      0        0.00
# 11                    MOVIMIENTO DE ACCION VECINAL     0      0        0.00
# 12                                 POLITICA OBRERA     0      0        0.00
# 13        MOVIMIENTO IZQUIERDA JUVENTUD Y DIGNIDAD     0      0        0.00
# 14                            PRINCIPIOS Y VALORES     0      0        0.00
# 15                                         blancos     1     10        4.10
# 16                                           nulos     1      3        1.23
# 17                                         comando     1      0        0.00
# 18                                      impugnados     1      0        0.00
# 19                                      recurridos     1      0        0.00
#
#     cant_sublistas
# 0                2
# 1                2
# 2                1
# 3                2
# 4                1
# 5                3
# 6                1
# 7                1
# 8                1
# 9                1
# 10               3
# 11               1
# 12               1
# 13               2
# 14               1
# 15               1
# 16               1
# 17               1
# 18               1
# 19               1
#
# [20 rows x 21 columns]

# %% [markdown]
# ¿Qué columnas tiene? ¿Cuántas filas? ¿Qué tipo de datos tiene cada columna?

# %%
df.info()

# %% [markdown]
# ¿Cómo vemos qué valores tiene una columna en particular? ¿Y una fila? ¿Qué valores únicos tiene una columna?
#
# Vamos a preguntarle todo esto a ChatGPT.

# %%
# Preguntar a ChatGPT

df["nom_seccion"]

# %%
df["nom_seccion"].value_counts()

# %% [markdown]
# Obtener la primer fila

# %% [markdown]
# Obtener todas las filas de La Matanza

# %% [markdown]
# Obtener todos los votos positivos o blancos

# %% [markdown]
# Obtener todos los votos positivos o blancos de la siguiente sección

# %%
seccion = [
    "La Matanza",
    "La Plata",
    "Lomas de Zamora",
    "Merlo",
    "Lanús",
    "Moreno",
    "Morón",
    "Luján",
    "Marcos Paz",
]

df = df[df["nom_seccion"].isin(seccion)]
df = df[(df["nom_tipo_voto"] == "positivo") | (df["nom_tipo_voto"] == "blancos")]

# %%
df

# %%
# Pivot table

df_pivot = df.pivot_table(index="nom_mesa", columns="nom_agrupacion", values="votos", aggfunc="sum")

df_pivot

# %%
# Agrego una columna con el total de votos
df_pivot["total"] = df_pivot.sum(axis=1)

# %% [markdown]
# Vamos a usar la librería `matplotlib` para hacer un histograma de la cantidad de votos por mesa.

# %%
from matplotlib import pyplot as plt

plt.hist(df_pivot["total"], bins=40)

# %% [markdown]
# Hay algunas mesas con muy pocos votos. Saquémoslas del análisis.

# %%
df_pivot["total"] > 100

# %%
# Saquemos las que tienen menos de 100 votos

df_pivot = df_pivot[df_pivot["total"] > 100]

# %%
renames = {
    "LA LIBERTAD AVANZA": "LLA",
    "FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD": "FIT",
    "UNION POR LA PATRIA": "UxP",
    "JUNTOS POR EL CAMBIO": "JUNTOS",
    "PRINCIPIOS Y VALORES": "PYV",
    "FRENTE LIBER.AR": "LIBER.AR",
    "HACEMOS POR NUESTRO PAIS": "HACEMOS",
    "MOVIMIENTO IZQUIERDA JUVENTUD Y DIGNIDAD": "MIJD",
    "UNION DEL CENTRO DEMOCRATICO": "UCD",
    "FRENTE PATRIOTA FEDERAL": "BIONDINI",
}

# Saco los NaN

df_pivot = df_pivot.dropna()
df_pivot = df_pivot[(df_pivot.T != 0).any()]


# Calculo porcentajes
df_non_normalized = df_pivot.copy()

df_pivot = df_pivot.div(df_pivot.sum(axis=1), axis=0)

# Rename columns

df_pivot = df_pivot.rename(columns=renames)


df_pivot

# %%
# Box plots de los porcentajes

df_pivot.boxplot(figsize=(20, 10))

# %% [markdown]
# Hagamos un mapa de calor de las correlaciones entre los votos a las distintas fuerzas.

# %%
corr = df_pivot.corr()

# Plot heatmap

import seaborn as sns

sns.heatmap(
    corr,
    xticklabels=corr.columns.values,
    yticklabels=corr.columns.values,
    cmap="viridis"
)

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np

# Fit linear model with constant for log log model

y = "LLA"
x = "UxP"


df_reg = df_pivot[[x, y]].copy()

df_reg = df_reg[(df_reg[y] > 0.05) & (df_reg[x] > 0.05)]

X = sm.add_constant(df_reg[x])
model = sm.OLS(df_reg[y], X).fit()

print(model.summary())

plt.scatter(df_reg[x], df_reg[y])

plt.plot(X, model.predict(X), color='red', linewidth=3)

plt.xlim(0, df_reg[x].max() + 0.1)
plt.xlabel(x)
plt.ylabel(y)

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np

# Fit linear model with constant for log log model

y = "LLA"
x = "JUNTOS"


df_reg = df_pivot[[x, y]].copy()

df_reg = df_reg[(df_reg[y] > 0.05)]# & (df_reg[x] > 0.05)]

X = sm.add_constant(df_reg[x])
model = sm.OLS(df_reg[y], X).fit()

print(model.summary())

plt.scatter(df_reg[x], df_reg[y])

plt.plot(X, model.predict(X), color='red', linewidth=3)

plt.xlim(0, df_reg[x].max() + 0.1)
plt.xlabel(x)
plt.ylabel(y)

# %% [markdown]
# ## Resultados 2021

# %%
df_2021 = pd.read_csv("https://raw.githubusercontent.com/finiteautomata/csc-2023/main/data/pba_2021.csv")

df_2021.info()

# %%
df_2021_la_matanza = df_2021[df_2021["seccion_nombre"] == "La Matanza"]

df_2021_la_matanza

# %%
df_2021_la_matanza["mesa_id"]

# %%
df[["cod_mesa", "nom_mesa"]]

# %%
df["mesa_id"] = df["cod_mesa"].apply(lambda x: int(x[:-1]))

# %%
df_la_matanza = df[df["nom_seccion"] == "La Matanza"]

# %%
df_2021_la_matanza["mesa_id"].unique()

# %%
df_la_matanza["mesa_id"].unique()

# %% [markdown]
# ## Ejercicios:
#
# 1. Analizar qué pasó con el voto en blanco
# 2. Buscar qué pasó en mesas donde alguna fuerza sacó 0 votos
# 3. Intentar reproducir votos 2021 vs votos 2023 (no garantizo que sea posible)
# 4. Lo que les interese más :-)
